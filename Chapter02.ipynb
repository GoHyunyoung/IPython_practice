# %% [markdown]
# #### #0629 #고현영 #Chapter2

# %% [markdown]
# #Ch.2 Introductory Examples

# %% [markdown]
# ## 2.1 bit.ly의 1.usa.gov 데이터

# %% [markdown]
# - 이미 웹에 저장되어 있는 txt파일을 URL로 접근하여 가져오기 위하여 urlib2 모듈 활용

# %%
pathUrl1='https://raw.githubusercontent.com/pydata/pydata-book/master/ch02/usagov_bitly_data2012-03-16-1331923249.txt'

# %%
import urllib

# %%
response = urllib.urlopen(pathUrl1)

# %%
responseLines=response.readline()

# %%
responseLines
#responseLines에 들어있는 Key : Value
# a : Mozilla\\ ...
# c : US
# nk : 1 ....
# Out:
# '{ "a": "Mozilla\\/5.0 (Windows NT 6.1; WOW64) AppleWebKit\\/535.11 (KHTML, like Gecko) Chrome\\/17.0.963.78 Safari\\/535.11", "c": "US", "nk": 1, "tz": "America\\/New_York", "gr": "MA", "g": "A6qOVH", "h": "wfLQtf", "l": "orofrog", "al": "en-US,en;q=0.8", "hh": "1.usa.gov", "r": "http:\\/\\/www.facebook.com\\/l\\/7AQEFzjSi\\/1.usa.gov\\/wfLQtf", "u": "http:\\/\\/www.ncbi.nlm.nih.gov\\/pubmed\\/22415991", "t": 1331923247, "hc": 1331822918, "cy": "Danvers", "ll": [ 42.576698, -70.954903 ] }\n'

# %%
import json

# %%
records=[json.loads(line) for line in response]
# json 모듈의 loads 함수로 내려받은 샘플파일을 한줄씩 읽는다.
# 이때 키워드가 a-b-c순으로 정렬된 형태로 들어옴

# %%
records
# Out:
# [{u'a': u'GoogleMaps/RochesterNY',
#   u'c': u'US',
#   u'cy': u'Provo',
#   u'g': u'mwszkS',
#   u'gr': u'UT',
#   u'h': u'mwszkS',
#   u'hc': 1308262393,
#   u'hh': u'j.mp',
#   u'l': u'bitly',
#   u'll': [40.218102, -111.613297],
#   u'nk': 0,
#   u'r': u'http://www.AwareMap.com/',
#   u't': 1331923249,
#   u'tz': u'America/Denver',
#   u'u': u'http://www.monroecounty.gov/etc/911/rss.php'},
#  {u'a': u'Mozilla/4.0 (compatible; MSIE 8.0; Windows NT 6.1; WOW64; Trident/4.0; SLCC2; .NET CLR 2.0.50727; .NET CLR 3.5.30729; .NET CLR 3.0.30729; Media Center PC 6.0; .NET4.0C; .NET4.0E; InfoPath.3)',
#   u'al': u'en-US',
#   u'c': u'US',
#   u'cy': u'Washington',
#   u'g': u'xxr3Qb',
#   u'gr': u'DC',
#   u'h': u'xxr3Qb',
#   u'hc': 1331919941,
#   u'hh': u'1.usa.gov',
#   u'l': u'bitly',
#   u'll': [38.9007, -77.043098],
#   u'nk': 1,
#   u'r': u'http://t.co/03elZC4Q',
#   u't': 1331923250,
#   u'tz': u'America/New_York',
# ...

# %%
records[0]
# Out:
# {u'a': u'GoogleMaps/RochesterNY',
#  u'c': u'US',
#  u'cy': u'Provo',
#  u'g': u'mwszkS',
#  u'gr': u'UT',
#  u'h': u'mwszkS',
#  u'hc': 1308262393,
#  u'hh': u'j.mp',
#  u'l': u'bitly',
#  u'll': [40.218102, -111.613297],
#  u'nk': 0,
#  u'r': u'http://www.AwareMap.com/',
#  u't': 1331923249,
#  u'tz': u'America/Denver',
#  u'u': u'http://www.monroecounty.gov/etc/911/rss.php'}

# %%
records[0]['tz']
#존재하는 key값('u'는 유니코드를 의미)
# Out:
# u'America/Denver'

# %%
print records[0]['tz']
# Out:
# America/Denver

# %% [markdown]
# ###2.1.1 순수 파이썬으로 표준시간대 세어보기

# %%
time_zones=[rec['tz'] for rec in records]
#records의 모든 아이템들이 'tz'를 키워드로 하고있는것은 아님 => Error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-150-d655476c38cb> in <module>()
# ----> 1 time_zones=[rec['tz'] for rec in records]
#       2 #records의 모든 아이템들이 'tz'를 키워드로 하고있는것은 아님 => Error
#
# KeyError: 'tz'

# %%
time_zone=[rec['tz'] for rec in records if 'tz' in rec]

# %%
time_zone[:10]
#10개까지

# %%
def get_counts(sequence):
    counts={}
    for x in sequence:
        if x in counts:
            counts[x]+=1
        else:
            counts[x]=1
    return counts

# %%
from collections import defaultdict

# %%
counts=get_counts(time_zone)

# %%
counts['America/New_York']

# %%
len(time_zone)

# %%
def top_counts(count_dict,n=10):  #def로 함수정의 #가장많이 등장하느 상의 10개의 tz
    value_key_pairs=[(count,tz) for tz, count in count_dict.items()]
    value_key_pairs.sort()
    return value_key_pairs[-n:]
#  list[0:3] = 인덱스 0부터 2까지
# list[:3] = 인덱스 0부터 2까지
# list[0:] = 인덱스 0부터 끝까지
# list[:-1] = list[:6]

# %%
top_counts(counts)

# %%
from collections import Counter

# %%
counts=Counter(time_zone)#파이썬 표준lib collections.Counter 클래스 사용

# %%
counts.most_common(10)

# %% [markdown]
# ###2.1.2 pandas로 표준시간대 세어보기

# %%
from pandas import DataFrame, Series #pandas의 주요 자료구조는 DataFrame(표,스프레드시트 같은 형태)

# %%
import pandas as pd; import numpy as np #pandas = pd, numpy = np (alias 기능, 별칭기능)

# %%
frame = DataFrame(records)

# %%
frame

# %%
frame['tz'][:10]

# %%
tz_counts = frame['tz'].value_counts() #frame['tz']에서 반환되는 Series객체에는 value_counts 메서드가 존재

# %%
tz_counts[:10] #파이썬 표준lib collections.Counter 클래스와 유사
#Series에도 슬라이싱기법 ex) [:10] 적용가능

# %%
clean_tz=frame['tz'].fillna('Missing')
#fillna는 NaN을 Missing 으로 처리

# %%
clean_tz

# %%
clean_tz[clean_tz=='']='Unknown' #records에서 비어있는 표준시간대는 'Unknown'으로

# %%
clean_tz

# %%
tz_counts=clean_tz.value_counts()

# %%
tz_counts[:10]

# %%
import matplotlib.pyplot as plt

# %%
tz_counts[:10].plot(kind='barh',rot=0);plt.show()

# %%
frame['a'][1]

# %%
frame['a'][50]

# %%
frame['a'][51]

# %%
results=Series([x.split()[0] for x in frame.a.dropna()])

# %%
results[:5]

# %%
result.value_counts()[:8]

# %%
cframe=frame[frame.a.notnull()]

# %%
operating_system=np.where(cframe['a'].str.contains('Windows'),'Windows','Not Windows')
#삼항연산자와 비슷한 기법 contains 하면 Windows 안하면 Not Windows

# %%
for x in operating_system[:5]:
    print x
# Out:
# Not Windows
# Windows
# Not Windows
# Windows
# Windows

# %%
by_tz_os = cframe.groupby(['tz',operating_system])

# %%
by_tz_os

# %%
type(by_tz_os)
# Out:
# pandas.core.groupby.DataFrameGroupBy

# %%
agg_counts=by_tz_os.size().unstack().fillna(0)

# %%
agg_counts[:10]
# Out:
#                                 Not Windows  Windows
# tz
#                                         245      276
# Africa/Cairo                              0        3
# Africa/Casablanca                         0        1
# Africa/Ceuta                              0        2
# Africa/Johannesburg                       0        1
# Africa/Lusaka                             0        1
# America/Anchorage                         4        1
# America/Argentina/Buenos_Aires            1        0
# America/Argentina/Cordoba                 0        1
# America/Argentina/Mendoza                 0        1

# %%
#오름차순으로 정렬
indexer = agg_counts.sum(1).argsort() #전체표준시간대의 순위

# %%
agg_counts
# Out:
#                                 Not Windows  Windows
# tz
#                                         245      276
# Africa/Cairo                              0        3
# Africa/Casablanca                         0        1
# Africa/Ceuta                              0        2
# Africa/Johannesburg                       0        1
# Africa/Lusaka                             0        1
# America/Anchorage                         4        1
# America/Argentina/Buenos_Aires            1        0
# America/Argentina/Cordoba                 0        1
# America/Argentina/Mendoza                 0        1
# America/Bogota                            1        2
# America/Caracas                           0        1
# America/Chicago                         115      285
# America/Chihuahua                         1        1
# America/Costa_Rica                        0        1
# America/Denver                          132       59
# America/Edmonton                          2        4
# ...

# %%
indexer[:]
# Out:
# tz
#                                   24
# Africa/Cairo                      20
# Africa/Casablanca                 21
# Africa/Ceuta                      92
# Africa/Johannesburg               87
# Africa/Lusaka                     53
# America/Anchorage                 54
# America/Argentina/Buenos_Aires    57
# America/Argentina/Cordoba         26
# America/Argentina/Mendoza         55
# America/Bogota                    62
# America/Caracas                   34
# America/Chicago                   60
# America/Chihuahua                 36
# America/Costa_Rica                37
# America/Denver                    27
# America/Edmonton                  76
# America/Guayaquil                 56
# America/Halifax                   89
# America/Indianapolis               2
# America/La_Paz                     4
# America/Lima                       5
# America/Los_Angeles                7
# America/Managua                    8
# America/Mazatlan                   9
# ...

# %%
#agg_counts에 take를 사용하여 행을 정렬된 순서 그대로 선택하고 마지막 10개 행만 잘라내기
count_subset = agg_counts.take(indexer)[-10:]

# %%
count_subset
# Out:
#                      Not Windows  Windows
# tz
# America/Sao_Paulo             13       20
# Europe/Madrid                 16       19
# Pacific/Honolulu               0       36
# Asia/Tokyo                     2       35
# Europe/London                 43       31
# America/Denver               132       59
# America/Los_Angeles          130      252
# America/Chicago              115      285
#                              245      276
# America/New_York             339      911

# %%
count_subset.plot(kind='barh',stacked=True);
#plt.show()
#stacked => True : 중첩막대, False : 2개의 막대로 그래프 표현

# %%
normed_subset = count_subset.div(count_subset.sum(1),axis=0)
#각 행의 총합을 1로 정규화

# %%
normed_subset.plot(kind='barh',stacked=True); plt.show()

# %% [markdown]
# ###2.2 MovieLens의 영화평점 데이터

# %%
pathUrl2='https://raw.githubusercontent.com/pydata/pydata-book/master/ch02/movielens/movies.dat'

# %%
import pandas as pd

# %%
unames=['user_id','gender','age','occupation','zip']
users=pd.read_table('https://raw.githubusercontent.com/pydata/pydata-book/master/ch02/movielens/users.dat',sep='::',header=None,names=unames)

rnames=['user_id','movie_id','rating','timestamp']
ratings=pd.read_table('https://raw.githubusercontent.com/pydata/pydata-book/master/ch02/movielens/ratings.dat',sep='::',header=None,names=rnames)

mnames=['movie_id','title','genres']
movies=pd.read_table('https://raw.githubusercontent.com/pydata/pydata-book/master/ch02/movielens/movies.dat',sep='::',header=None,names=mnames)

# %%
users[:5]
# Out:
#    user_id gender  age  occupation    zip
# 0        1      F    1          10  48067
# 1        2      M   56          16  70072
# 2        3      M   25          15  55117
# 3        4      M   45           7  02460
# 4        5      M   25          20  55455

# %%
ratings[:5]
# Out:
#    user_id  movie_id  rating  timestamp
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %%
movies[:5]
# Out:
#    movie_id                               title                        genres
# 0         1                    Toy Story (1995)   Animation|Children's|Comedy
# 1         2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2         3             Grumpier Old Men (1995)                Comedy|Romance
# 3         4            Waiting to Exhale (1995)                  Comedy|Drama
# 4         5  Father of the Bride Part II (1995)                        Comedy

# %%
ratings
# Out:
#          user_id  movie_id  rating  timestamp
# 0              1      1193       5  978300760
# 1              1       661       3  978302109
# 2              1       914       3  978301968
# 3              1      3408       4  978300275
# 4              1      2355       5  978824291
# 5              1      1197       3  978302268
# 6              1      1287       5  978302039
# 7              1      2804       5  978300719
# 8              1       594       4  978302268
# 9              1       919       4  978301368
# 10             1       595       5  978824268
# 11             1       938       4  978301752
# 12             1      2398       4  978302281
# 13             1      2918       4  978302124
# 14             1      1035       5  978301753
# 15             1      2791       4  978302188
# 16             1      2687       3  978824268
# 17             1      2018       4  978301777
# 18             1      3105       5  978301713
# ...

# %%
#3가지의 데이터를 하나로 병합 -> pandas의 merge 함수를 이용
data=pd.merge(pd.merge(ratings,users),movies)

# %%
data
# Out:
#          user_id  movie_id  rating   timestamp gender  age  occupation    zip  \
# 0              1      1193       5   978300760      F    1          10  48067
# 1              2      1193       5   978298413      M   56          16  70072
# 2             12      1193       4   978220179      M   25          12  32793
# 3             15      1193       4   978199279      M   25           7  22903
# 4             17      1193       5   978158471      M   50           1  95350
# 5             18      1193       4   978156168      F   18           3  95825
# 6             19      1193       5   982730936      M    1          10  48073
# 7             24      1193       5   978136709      F   25           7  10023
# 8             28      1193       3   978125194      F   25           1  14607
# 9             33      1193       5   978557765      M   45           3  55421
# 10            39      1193       5   978043535      M   18           4  61820
# ...

# %%
data.ix[0]
#행의 값을 확인할때는 ix사용
# Out:
# user_id                                            1
# movie_id                                        1193
# rating                                             5
# timestamp                                  978300760
# gender                                             F
# age                                                1
# occupation                                        10
# zip                                            48067
# title         One Flew Over the Cuckoo's Nest (1975)
# genres                                         Drama
# Name: 0, dtype: object

# %%
mean_ratings=data.pivot_table('rating',index='title', columns='gender',aggfunc='mean')
#rows => index, cols => columns 로 변경(가로축 title, 세로축 gender, aggregatefunc deafult  = mean)

# %%
mean_ratings[:5]
# Out:
# gender                                F         M
# title
# $1,000,000 Duck (1971)         3.375000  2.761905
# 'Night Mother (1986)           3.388889  3.352941
# 'Til There Was You (1997)      2.675676  2.733333
# 'burbs, The (1989)             2.793478  2.962085
# ...And Justice for All (1979)  3.828571  3.689024

# %%
ratings_by_title = data.groupby('title').size()
##########################################################

# %%
ratings_by_title[:10]
# Out:
# title
# $1,000,000 Duck (1971)                 4
# 'Night Mother (1986)                   7
# 'Til There Was You (1997)             10
# 'burbs, The (1989)                    48
# ...And Justice for All (1979)         24
# 10 Things I Hate About You (1999)    104
# 101 Dalmatians (1961)                 80
# 101 Dalmatians (1996)                 46
# 12 Angry Men (1957)                   80
# 13th Warrior, The (1999)             111
# dtype: int64

# %%
active_titles = ratings_by_title.index[ratings_by_title >= 250] 
#250건 이상의 평점 정보가 있는 영화의 title만 가져오기

# %%
active_titles
# Out:
# Index([u'Airplane! (1980)', u'Alien (1979)', u'Aliens (1986)',
#        u'American Beauty (1999)', u'Back to the Future (1985)',
#        u'Being John Malkovich (1999)', u'Braveheart (1995)',
#        u'Bug's Life, A (1998)', u'Chicken Run (2000)',
#        u'E.T. the Extra-Terrestrial (1982)', u'Fargo (1996)',
#        u'Forrest Gump (1994)', u'Fugitive, The (1993)', u'Galaxy Quest (1999)',
#        u'Ghostbusters (1984)', u'Gladiator (2000)', u'Godfather, The (1972)',
#        u'Groundhog Day (1993)', u'Jurassic Park (1993)',
#        u'L.A. Confidential (1997)', u'Matrix, The (1999)',
#        u'Men in Black (1997)', u'Mission: Impossible (1996)',
#        u'One Flew Over the Cuckoo's Nest (1975)',
#        u'Princess Bride, The (1987)', u'Pulp Fiction (1994)',
#        u'Raiders of the Lost Ark (1981)', u'Saving Private Ryan (1998)',
#        u'Schindler's List (1993)', u'Shakespeare in Love (1998)',
#        u'Shawshank Redemption, The (1994)',
# ...

# %%
mean_ratings = mean_ratings.ix[active_titles]

# %%
mean_ratings
# Out:
# gender                                                     F         M
# title
# Airplane! (1980)                                    3.945205  4.150215
# Alien (1979)                                        3.707317  4.158120
# Aliens (1986)                                       3.707317  4.197368
# American Beauty (1999)                              4.122449  4.332487
# Back to the Future (1985)                           3.905882  4.076923
# Being John Malkovich (1999)                         4.136986  4.069959
# Braveheart (1995)                                   4.023529  4.335570
# Bug's Life, A (1998)                                3.984615  3.900524
# Chicken Run (2000)                                  3.988506  3.893204
# E.T. the Extra-Terrestrial (1982)                   4.227273  3.995851
# Fargo (1996)                                        4.263736  4.215139
# Forrest Gump (1994)                                 4.126582  4.101695
# ...

# %%
mean_ratings.ix[active_titles]
# Out:
# gender                                                     F         M
# title
# Airplane! (1980)                                    3.945205  4.150215
# Alien (1979)                                        3.707317  4.158120
# Aliens (1986)                                       3.707317  4.197368
# American Beauty (1999)                              4.122449  4.332487
# Back to the Future (1985)                           3.905882  4.076923
# Being John Malkovich (1999)                         4.136986  4.069959
# Braveheart (1995)                                   4.023529  4.335570
# Bug's Life, A (1998)                                3.984615  3.900524
# Chicken Run (2000)                                  3.988506  3.893204
# E.T. the Extra-Terrestrial (1982)                   4.227273  3.995851
# Fargo (1996)                                        4.263736  4.215139
# Forrest Gump (1994)                                 4.126582  4.101695
# ...

# %%
#여성에게 높은 평점을 받은 영화목록 확인(F열을 내림차순으로 정렬)
top_female_ratings = mean_ratings.sort_index(by='F', ascending=False)

# %%
top_female_ratings[:10]
# Out:
# gender                                            F         M
# title
# Schindler's List (1993)                    4.627907  4.500000
# Sixth Sense, The (1999)                    4.436170  4.369231
# Shawshank Redemption, The (1994)           4.421687  4.551867
# Raiders of the Lost Ark (1981)             4.354430  4.481848
# Star Wars: Episode IV - A New Hope (1977)  4.298077  4.495702
# Fargo (1996)                               4.263736  4.215139
# Princess Bride, The (1987)                 4.260417  4.324000
# Wizard of Oz, The (1939)                   4.256410  4.290698
# Godfather, The (1972)                      4.235294  4.521739
# E.T. the Extra-Terrestrial (1982)          4.227273  3.995851

# %% [markdown]
# ### 2.2.1 평점 차이 구하기

# %%
#남겨의 호불호가 갈리는 영화 찾기(mean_rating에 평균 평점의 차이를 담을수 있는 열을 하나 추가하여 그 열을 기준으로 정렬)
mean_ratings['diff']=mean_ratings['M']-mean_ratings['F']

# %%
sorted_by_diff = mean_ratings.sort_index(by='diff')
#default 오름차순으로 정렬

# %%
sorted_by_diff[:15]
# Out:
# gender                                                   F         M      diff
# title
# E.T. the Extra-Terrestrial (1982)                 4.227273  3.995851 -0.231422
# Men in Black (1997)                               3.925000  3.714286 -0.210714
# Galaxy Quest (1999)                               4.052632  3.855670 -0.196961
# Star Wars: Episode I - The Phantom Menace (1999)  3.507246  3.357143 -0.150104
# Schindler's List (1993)                           4.627907  4.500000 -0.127907
# Chicken Run (2000)                                3.988506  3.893204 -0.095302
# Bug's Life, A (1998)                              3.984615  3.900524 -0.084092
# Speed (1994)                                      3.634921  3.565657 -0.069264
# Being John Malkovich (1999)                       4.136986  4.069959 -0.067027
# Sixth Sense, The (1999)                           4.436170  4.369231 -0.066939
# Toy Story (1995)                                  4.218391  4.156951 -0.061440
# ...

# %%
sorted_by_diff[::-1][:15]
##### [::-1][:15] ######
# Out:
# gender                                                    F         M  \
# title
# Jurassic Park (1993)                               3.435644  3.939828
# Groundhog Day (1993)                               3.583333  4.084677
# Aliens (1986)                                      3.707317  4.197368
# Alien (1979)                                       3.707317  4.158120
# Terminator, The (1984)                             3.854167  4.223108
# Matrix, The (1999)                                 4.087500  4.450746
# Saving Private Ryan (1998)                         4.123457  4.472050
# Total Recall (1990)                                3.425532  3.748988
# L.A. Confidential (1997)                           3.965116  4.288066
# Braveheart (1995)                                  4.023529  4.335570
# Terminator 2: Judgment Day (1991)                  3.857143  4.168168
# Godfather, The (1972)                              4.235294  4.521739
# ...

# %%
#성별에 상관없이 호불호가 극명하게 나뉘는 영화찾기(평점의 분산 혹은 표준편차를 통해 측정)
#평점의 표준편차
rating_std_by_title = data.groupby('title')['rating'].std()

# %%
#active_titles만 선택
rating_std_by_title=rating_std_by_title.ix[active_titles]

# %%
rating_std_by_title.order(ascending=False)[:10]
#내림차순으로 정렬
# Out:
# title
# Titanic (1997)                                      1.145290
# Star Wars: Episode I - The Phantom Menace (1999)    1.123447
# Being John Malkovich (1999)                         1.055136
# American Beauty (1999)                              1.020133
# Forrest Gump (1994)                                 1.003704
# Pulp Fiction (1994)                                 1.002194
# Mission: Impossible (1996)                          0.988382
# Groundhog Day (1993)                                0.974830
# Jurassic Park (1993)                                0.953811
# Speed (1994)                                        0.943559
# Name: rating, dtype: float64

# %% [markdown]
# ##2.3 신생아 이름

# %%
import pandas as pd

# %%
babies=['name','sex','births']
names=pd.read_table('https://raw.githubusercontent.com/pydata/pydata-book/master/ch02/names/yob1880.txt',sep=',',header=None,names=babies)
###### names와 head #####

# %%
names.head(10)
# Out:
#         name sex  births
# 0       Mary   F    7065
# 1       Anna   F    2604
# 2       Emma   F    2003
# 3  Elizabeth   F    1939
# 4     Minnie   F    1746
# 5   Margaret   F    1578
# 6        Ida   F    1472
# 7      Alice   F    1414
# 8     Bertha   F    1320
# 9      Sarah   F    1288

# %%
names1880=pd.read_csv('https://raw.githubusercontent.com/pydata/pydata-book/master/ch02/names/yob1880.txt',names=babies)
# ' , ' 쉼표로 구분되어있는 경우 pandas.read_CSV 메서드를 이용하여 간편하게 구분하는것이 가능

# %%
names1880
# 각연도별로 최소 5명이상 중복되는 이름만 포함하고 있음
# Out:
#            name sex  births
# 0          Mary   F    7065
# 1          Anna   F    2604
# 2          Emma   F    2003
# 3     Elizabeth   F    1939
# 4        Minnie   F    1746
# 5      Margaret   F    1578
# 6           Ida   F    1472
# 7         Alice   F    1414
# 8        Bertha   F    1320
# 9         Sarah   F    1288
# 10        Annie   F    1258
# 11        Clara   F    1226
# 12         Ella   F    1156
# 13     Florence   F    1063
# 14         Cora   F    1045
# 15       Martha   F    1040
# 16        Laura   F    1012
# 17       Nellie   F     995
# 18        Grace   F     982
# 19       Carrie   F     949
# 20        Maude   F     858
# 21        Mabel   F     808
# 22       Bessie   F     794
# 23       Jennie   F     793
# 24     Gertrude   F     787
# 25        Julia   F     783
# 26       Hattie   F     769
# 27        Edith   F     768
# 28       Mattie   F     704
# 29         Rose   F     700
# ...         ...  ..     ...
# 1970      Philo   M       5
# ...

# %%
names.groupby('sex').births.sum()
#출생수를 모두합한 값을 해당연도에 전체 출생수로 가정
# Out:
# sex
# F     90993
# M    110493
# Name: births, dtype: int64

# %%
years = range(1880,2011)

pieces = []
columns = ['name', 'sex', 'births']

for year in years:
    path='https://raw.githubusercontent.com/pydata/pydata-book/master/ch02/names/yob%d.txt' % year
    frame = pd.read_csv(path,names=columns)
    
    frame['year'] = year
    pieces.append(frame)

#1880년부터 2010년까지의 데이터를 하나의 DataFrame으로 종합
names = pd.concat(pieces,ignore_index=True)

# %%
names
# Out:
#               name sex  births  year
# 0             Mary   F    7065  1880
# 1             Anna   F    2604  1880
# 2             Emma   F    2003  1880
# 3        Elizabeth   F    1939  1880
# 4           Minnie   F    1746  1880
# 5         Margaret   F    1578  1880
# 6              Ida   F    1472  1880
# 7            Alice   F    1414  1880
# 8           Bertha   F    1320  1880
# 9            Sarah   F    1288  1880
# 10           Annie   F    1258  1880
# 11           Clara   F    1226  1880
# 12            Ella   F    1156  1880
# 13        Florence   F    1063  1880
# 14            Cora   F    1045  1880
# 15          Martha   F    1040  1880
# 16           Laura   F    1012  1880
# 17          Nellie   F     995  1880
# 18           Grace   F     982  1880
# 19          Carrie   F     949  1880
# 20           Maude   F     858  1880
# 21           Mabel   F     808  1880
# 22          Bessie   F     794  1880
# 23          Jennie   F     793  1880
# ...

# %%
total_births = names.pivot_table('births',index='year',columns='sex',aggfunc=sum)
#연도나 성별에 따른 데이터 정리

# %%
total_births.tail()
#tail()은 마지막 5개 데이터만 추출
# Out:
# sex         F        M
# year
# 2006  1896468  2050234
# 2007  1916888  2069242
# 2008  1883645  2032310
# 2009  1827643  1973359
# 2010  1759010  1898382

# %%
total_births.plot(title='Total births by sex and year'); plt.show()
#이름이 각 출생수에서 차지하는 비율계산해보기

# %%
def add_prop(group):
    births=group.births.astype(float)
    
    group['prop']=births/ births.sum()
    return group

#group에 prop 열을 추가하고 연산결과를 입력

# %%
names = names.groupby(['year','sex']).apply(add_prop);
#names에 'prop' 추가

# %%
names
# Out:
#               name sex  births  year      prop
# 0             Mary   F    7065  1880  0.077643
# 1             Anna   F    2604  1880  0.028618
# 2             Emma   F    2003  1880  0.022013
# 3        Elizabeth   F    1939  1880  0.021309
# 4           Minnie   F    1746  1880  0.019188
# 5         Margaret   F    1578  1880  0.017342
# 6              Ida   F    1472  1880  0.016177
# 7            Alice   F    1414  1880  0.015540
# 8           Bertha   F    1320  1880  0.014507
# 9            Sarah   F    1288  1880  0.014155
# 10           Annie   F    1258  1880  0.013825
# 11           Clara   F    1226  1880  0.013474
# 12            Ella   F    1156  1880  0.012704
# 13        Florence   F    1063  1880  0.011682
# 14            Cora   F    1045  1880  0.011484
# 15          Martha   F    1040  1880  0.011429
# 16           Laura   F    1012  1880  0.011122
# 17          Nellie   F     995  1880  0.010935
# 18           Grace   F     982  1880  0.010792
# ...

# %%
#prop열의 합이 1이 맞느지 확인하는 sanity check
np.allclose(names.groupby(['year','sex']).prop.sum(),1)
##### 'groupby' #####
# Out:
# True

# %%
#각 연도별 성별에 따른 빈도수가 가장 높은 이름 1,000개 추출
def get_top1000(group):
    return group.sort_index(by='births',ascending=False)[:1000]

# %%
grouped = names.groupby(['year','sex'])

# %%
top1000 = grouped.apply(get_top1000)

# %%
top1000
# Out:
#                        name sex  births  year      prop
# year sex
# 1880 F   0             Mary   F    7065  1880  0.077643
#          1             Anna   F    2604  1880  0.028618
#          2             Emma   F    2003  1880  0.022013
#          3        Elizabeth   F    1939  1880  0.021309
#          4           Minnie   F    1746  1880  0.019188
#          5         Margaret   F    1578  1880  0.017342
#          6              Ida   F    1472  1880  0.016177
#          7            Alice   F    1414  1880  0.015540
#          8           Bertha   F    1320  1880  0.014507
#          9            Sarah   F    1288  1880  0.014155
#          10           Annie   F    1258  1880  0.013825
#          11           Clara   F    1226  1880  0.013474
#          12            Ella   F    1156  1880  0.012704
#          13        Florence   F    1063  1880  0.011682
#          14            Cora   F    1045  1880  0.011484
#          15          Martha   F    1040  1880  0.011429
# ...

# %%
boys = top1000[top1000.sex == 'M']

# %%
girls = top1000[top1000.sex == 'F']

# %%
total_births=top1000.pivot_table('births',index='year',columns='name',aggfunc=sum)

# %%
total_births
# Out:
# name  Aaden  Aaliyah  Aarav  Aaron  Aarush  Ab  Abagail  Abb  Abbey  Abbie  \
# year
# 1880    NaN      NaN    NaN    102     NaN NaN      NaN  NaN    NaN     71
# 1881    NaN      NaN    NaN     94     NaN NaN      NaN  NaN    NaN     81
# 1882    NaN      NaN    NaN     85     NaN NaN      NaN  NaN    NaN     80
# 1883    NaN      NaN    NaN    105     NaN NaN      NaN  NaN    NaN     79
# 1884    NaN      NaN    NaN     97     NaN NaN      NaN  NaN    NaN     98
# 1885    NaN      NaN    NaN     88     NaN   6      NaN  NaN    NaN     88
# 1886    NaN      NaN    NaN     86     NaN NaN      NaN  NaN    NaN     84
# 1887    NaN      NaN    NaN     78     NaN NaN      NaN  NaN    NaN    104
# 1888    NaN      NaN    NaN     90     NaN NaN      NaN  NaN    NaN    137
# 1889    NaN      NaN    NaN     85     NaN NaN      NaN  NaN    NaN    107
# 1890    NaN      NaN    NaN     96     NaN NaN      NaN    6    NaN    140
# ...

# %%
subset=total_births[['John','Harry','Mary','Marilyn']]

# %%
subset.plot(subplots=True, figsize=(12,10), grid=False,title="Number of births per year"); plt.show()

# %%
#다양한 이름을 사용하는 경향 파악
table = top1000.pivot_table('prop',index='year',columns='sex',aggfunc='sum')

# %%
table.plot(title='Sum of table1000.prop by year and sex', yticks=np.linspace(0,1.2,13), xticks=range(1880,2020,10)); plt.show()

# %%
df = boys[boys.year == 2010]

# %%
df
# Out:
#                          name sex  births  year      prop
# year sex
# 2010 M   1676644        Jacob   M   21875  2010  0.011523
#          1676645        Ethan   M   17866  2010  0.009411
#          1676646      Michael   M   17133  2010  0.009025
#          1676647       Jayden   M   17030  2010  0.008971
#          1676648      William   M   16870  2010  0.008887
#          1676649    Alexander   M   16634  2010  0.008762
#          1676650         Noah   M   16281  2010  0.008576
#          1676651       Daniel   M   15679  2010  0.008259
#          1676652        Aiden   M   15403  2010  0.008114
#          1676653      Anthony   M   15364  2010  0.008093
#          1676654       Joshua   M   15238  2010  0.008027
#          1676655        Mason   M   14728  2010  0.007758
#          1676656  Christopher   M   14135  2010  0.007446
#          1676657       Andrew   M   14093  2010  0.007424
#          1676658        David   M   14042  2010  0.007397
# ...

# %%
prop_cumsum = df.sort_index( by = 'prop', ascending=False).prop.cumsum()

# %%
prop_cumsum[:10]
# Out:
# year  sex
# 2010  M    1676644    0.011523
#            1676645    0.020934
#            1676646    0.029959
#            1676647    0.038930
#            1676648    0.047817
#            1676649    0.056579
#            1676650    0.065155
#            1676651    0.073414
#            1676652    0.081528
#            1676653    0.089621
# Name: prop, dtype: float64

# %%
prop_cumsum.searchsorted(0.5)
# Out:
# array([116], dtype=int64)

# %%
df = boys[boys.year == 1900]

# %%
in1900 = df.sort_index(by='prop',ascending=False).prop.cumsum()

# %%
in1900.searchsorted(0.5)+1
# Out:
# array([25], dtype=int64)

# %%
def get_quantile_count(group, q=0.5):
    group = group.sort_index(by='prop',ascending = False)
    return group.prop.cumsum().searchsorted(q) +1

# %%
diversity = top1000.groupby(['year','sex']).apply(get_quantile_count)
diversity = diversity.unstack('sex')

# %%
diversity.head()
# Out:
# sex      F     M
# year
# 1880  [38]  [14]
# 1881  [38]  [14]
# 1882  [38]  [15]
# 1883  [39]  [15]
# 1884  [39]  [16]

# %%
diversity.plot(title = "Number of popular names in top 50%")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-502-5be1b0e06bc6> in <module>()
# ----> 1 diversity.plot(title = "Number of popular names in top 50%")
#
# C:\Users\GoHyunyoung98\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\tools\plotting.pyc in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2486                  yerr=yerr, xerr=xerr,
#    2487                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 2488                  **kwds)
#    2489
#    2490
#
# C:\Users\GoHyunyoung98\AppData\Local\Enthought\Canopy\User\lib\site-packages\pandas\tools\plotting.pyc in _plot(data, x, y, subplots, ax, kind, **kwds)
# ...
